# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":  city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pangnirtung
# Processing Record 2 of Set 1 | olinda
# Processing Record 3 of Set 1 | payakumbuh
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | nizhneivkino
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | meulaboh
# Processing Record 14 of Set 1 | college
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | nusaybin
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | oistins
# Processing Record 20 of Set 1 | weiswampach
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | broken hill
# Processing Record 23 of Set 1 | billings
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | perafita
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | inhambane
# Processing Record 31 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | salalah
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | morropon
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | puerto baquerizo moreno
# Processing Record 39 of Set 1 | half moon bay
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | leningradskiy
# Processing Record 42 of Set 1 | nokaneng
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | cidreira
# Processing Record 45 of Set 1 | sturgeon bay
# Processing Record 46 of Set 1 | obigarm
# Processing Record 47 of Set 1 | nome
# Processing Record 48 of Set 1 | basoko
# Processing Record 49 of Set 1 | esfarayen
# Processing Record 50 of Set 1 | lohja
# Processing Record 1 of Set 2 | whitehorse
# Processing Record 2 of Set 2 | tacuati
# Processing Record 3 of Set 2 | tilichiki
# Processing Record 4 of Set 2 | luebo
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | ugoofaaru
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | hualmay
# Processing Record 10 of Set 2 | havoysund
# Processing Record 11 of Set 2 | beringovskiy
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | kudahuvadhoo
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | vanavara
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | olga
# Processing Record 19 of Set 2 | voljevac
# Processing Record 20 of Set 2 | kamenka
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | zheleznodorozhnyy
# Processing Record 23 of Set 2 | bafra
# Processing Record 24 of Set 2 | vao
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | rincon
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | khurda
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | barra da estiva
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 2 | northam
# Processing Record 37 of Set 2 | hoorn
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | lorengau
# Processing Record 40 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 2 | praia da vitoria
# Processing Record 42 of Set 2 | xining
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | margate
# Processing Record 45 of Set 2 | wanning
# Processing Record 46 of Set 2 | naze
# Processing Record 47 of Set 2 | tromso
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | rio gallegos
# Processing Record 3 of Set 3 | buchanan
# Processing Record 4 of Set 3 | itarema
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | palora
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | kichera
# Processing Record 9 of Set 3 | yerbogachen
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | mochalishche
# Processing Record 15 of Set 3 | dalvik
# Processing Record 16 of Set 3 | tucumcari
# Processing Record 17 of Set 3 | la asuncion
# Processing Record 18 of Set 3 | tostamaa
# City not found. Skipping...
# Processing Record 19 of Set 3 | sobolevo
# Processing Record 20 of Set 3 | skelleftea
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | holland
# Processing Record 23 of Set 3 | aklavik
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | aasiaat
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | zhigansk
# Processing Record 28 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | oussouye
# Processing Record 31 of Set 3 | acarau
# Processing Record 32 of Set 3 | slave lake
# Processing Record 33 of Set 3 | bayan
# Processing Record 34 of Set 3 | yaypan
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | tual
# Processing Record 37 of Set 3 | talara
# Processing Record 38 of Set 3 | nouadhibou
# Processing Record 39 of Set 3 | alta floresta
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | west bay
# Processing Record 42 of Set 3 | belmonte
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | sorland
# Processing Record 46 of Set 3 | banda aceh
# Processing Record 47 of Set 3 | lasa
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | veraval
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | gibsons
# Processing Record 3 of Set 4 | cumpas
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | camacupa
# Processing Record 8 of Set 4 | peleduy
# Processing Record 9 of Set 4 | te anau
# Processing Record 10 of Set 4 | cherskiy
# Processing Record 11 of Set 4 | langxiang
# Processing Record 12 of Set 4 | saint-francois
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | milas
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | treinta y tres
# Processing Record 19 of Set 4 | auerbach
# Processing Record 20 of Set 4 | gagra
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | barrow
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | pacific grove
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | uribia
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | neepawa
# Processing Record 29 of Set 4 | christchurch
# Processing Record 30 of Set 4 | maceio
# Processing Record 31 of Set 4 | toulepleu
# City not found. Skipping...
# Processing Record 32 of Set 4 | iskele
# Processing Record 33 of Set 4 | krasnoselkup
# Processing Record 34 of Set 4 | dandong
# Processing Record 35 of Set 4 | trossingen
# Processing Record 36 of Set 4 | najran
# Processing Record 37 of Set 4 | numaran
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | pozzallo
# Processing Record 41 of Set 4 | plettenberg bay
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | tibati
# Processing Record 44 of Set 4 | san luis
# Processing Record 45 of Set 4 | steubenville
# Processing Record 46 of Set 4 | kizema
# Processing Record 47 of Set 4 | ancud
# Processing Record 48 of Set 4 | udachnyy
# Processing Record 49 of Set 4 | jurado
# Processing Record 50 of Set 4 | general higinio morinigo
# Processing Record 1 of Set 5 | yaan
# Processing Record 2 of Set 5 | nouakchott
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | opuwo
# Processing Record 5 of Set 5 | saint-augustin
# Processing Record 6 of Set 5 | namibe
# Processing Record 7 of Set 5 | merauke
# Processing Record 8 of Set 5 | zenzeli
# Processing Record 9 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 5 | yumen
# Processing Record 11 of Set 5 | goure
# Processing Record 12 of Set 5 | roald
# Processing Record 13 of Set 5 | krasnogorskiy
# Processing Record 14 of Set 5 | ust-nera
# Processing Record 15 of Set 5 | minsk
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | cozumel
# Processing Record 18 of Set 5 | kawambwa
# Processing Record 19 of Set 5 | deputatskiy
# Processing Record 20 of Set 5 | kendari
# Processing Record 21 of Set 5 | pangai
# Processing Record 22 of Set 5 | sakskobing
# Processing Record 23 of Set 5 | havre-saint-pierre
# Processing Record 24 of Set 5 | santa cruz
# Processing Record 25 of Set 5 | birnin kebbi
# Processing Record 26 of Set 5 | lata
# Processing Record 27 of Set 5 | buenos aires
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | salekhard
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | acapulco
# Processing Record 32 of Set 5 | namie
# Processing Record 33 of Set 5 | arlit
# Processing Record 34 of Set 5 | cabedelo
# Processing Record 35 of Set 5 | san patricio
# Processing Record 36 of Set 5 | grand gaube
# Processing Record 37 of Set 5 | severo-kurilsk
# Processing Record 38 of Set 5 | iralaya
# Processing Record 39 of Set 5 | markova
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | pisco
# Processing Record 42 of Set 5 | kashi
# Processing Record 43 of Set 5 | bassano
# Processing Record 44 of Set 5 | champerico
# Processing Record 45 of Set 5 | portmore
# Processing Record 46 of Set 5 | sao borja
# Processing Record 47 of Set 5 | aloleng
# Processing Record 48 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 5 | yuancheng
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | kogota
# Processing Record 3 of Set 6 | yulara
# Processing Record 4 of Set 6 | port blair
# Processing Record 5 of Set 6 | tuatapere
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | caravelas
# Processing Record 8 of Set 6 | yar-sale
# Processing Record 9 of Set 6 | groditz
# City not found. Skipping...
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 6 | raudeberg
# Processing Record 13 of Set 6 | mahibadhoo
# Processing Record 14 of Set 6 | coquimbo
# Processing Record 15 of Set 6 | tessalit
# Processing Record 16 of Set 6 | marzuq
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | mahajanga
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | hithadhoo
# Processing Record 21 of Set 6 | kavieng
# Processing Record 22 of Set 6 | rosarito
# Processing Record 23 of Set 6 | bonfim
# Processing Record 24 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 6 | westfield
# Processing Record 26 of Set 6 | port hardy
# Processing Record 27 of Set 6 | teguldet
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | talakan
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | sechura
# Processing Record 32 of Set 6 | bichura
# Processing Record 33 of Set 6 | purpe
# Processing Record 34 of Set 6 | amapa
# Processing Record 35 of Set 6 | beberibe
# Processing Record 36 of Set 6 | faanui
# Processing Record 37 of Set 6 | borogontsy
# Processing Record 38 of Set 6 | kaitangata
# Processing Record 39 of Set 6 | ballina
# Processing Record 40 of Set 6 | iqaluit
# Processing Record 41 of Set 6 | victor harbor
# Processing Record 42 of Set 6 | cap malheureux
# Processing Record 43 of Set 6 | sisimiut
# Processing Record 44 of Set 6 | narsaq
# Processing Record 45 of Set 6 | palmas
# Processing Record 46 of Set 6 | omboue
# Processing Record 47 of Set 6 | graaff-reinet
# Processing Record 48 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 6 | natal
# Processing Record 50 of Set 6 | lodwar
# Processing Record 1 of Set 7 | vikulovo
# Processing Record 2 of Set 7 | xuddur
# Processing Record 3 of Set 7 | quatre cocos
# Processing Record 4 of Set 7 | kruisfontein
# Processing Record 5 of Set 7 | lichuan
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | san quintin
# Processing Record 8 of Set 7 | mehamn
# Processing Record 9 of Set 7 | avera
# Processing Record 10 of Set 7 | luanda
# Processing Record 11 of Set 7 | kokopo
# Processing Record 12 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 7 | kpandae
# Processing Record 16 of Set 7 | miranda
# Processing Record 17 of Set 7 | palmer
# Processing Record 18 of Set 7 | phun phin
# City not found. Skipping...
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | kidal
# Processing Record 21 of Set 7 | sao sebastiao
# Processing Record 22 of Set 7 | abha
# Processing Record 23 of Set 7 | haines junction
# Processing Record 24 of Set 7 | ubinskoye
# Processing Record 25 of Set 7 | beloha
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | keti bandar
# Processing Record 28 of Set 7 | hoganas
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 7 | vostok
# Processing Record 32 of Set 7 | mamontovo
# Processing Record 33 of Set 7 | sahawar
# Processing Record 34 of Set 7 | labuhan
# Processing Record 35 of Set 7 | abu samrah
# Processing Record 36 of Set 7 | homer
# Processing Record 37 of Set 7 | camacha
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | mahon
# Processing Record 40 of Set 7 | cervo
# Processing Record 41 of Set 7 | ahome
# Processing Record 42 of Set 7 | fairlie
# Processing Record 43 of Set 7 | belm
# Processing Record 44 of Set 7 | balingasay
# Processing Record 45 of Set 7 | balikpapan
# Processing Record 46 of Set 7 | vardo
# Processing Record 47 of Set 7 | andros town
# Processing Record 48 of Set 7 | lagoa
# Processing Record 49 of Set 7 | rosetta
# Processing Record 50 of Set 7 | aromashevo
# Processing Record 1 of Set 8 | conway
# Processing Record 2 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 8 | kaeo
# Processing Record 4 of Set 8 | douentza
# Processing Record 5 of Set 8 | imeni poliny osipenko
# Processing Record 6 of Set 8 | manacapuru
# Processing Record 7 of Set 8 | umm lajj
# Processing Record 8 of Set 8 | keningau
# Processing Record 9 of Set 8 | kroya
# Processing Record 10 of Set 8 | bahia honda
# Processing Record 11 of Set 8 | manakara
# Processing Record 12 of Set 8 | sao filipe
# Processing Record 13 of Set 8 | kentau
# Processing Record 14 of Set 8 | chitral
# Processing Record 15 of Set 8 | katobu
# Processing Record 16 of Set 8 | placido de castro
# Processing Record 17 of Set 8 | itoman
# Processing Record 18 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 8 | ekhabi
# Processing Record 20 of Set 8 | clyde river
# Processing Record 21 of Set 8 | marrakesh
# Processing Record 22 of Set 8 | khani
# Processing Record 23 of Set 8 | ossora
# Processing Record 24 of Set 8 | noumea
# Processing Record 25 of Set 8 | qinnan
# Processing Record 26 of Set 8 | okato
# Processing Record 27 of Set 8 | srisailam
# Processing Record 28 of Set 8 | hobyo
# Processing Record 29 of Set 8 | vagur
# Processing Record 30 of Set 8 | estevan
# Processing Record 31 of Set 8 | nishihara
# Processing Record 32 of Set 8 | parana
# Processing Record 33 of Set 8 | benguela
# Processing Record 34 of Set 8 | puerto barrios
# Processing Record 35 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 8 | muros
# Processing Record 37 of Set 8 | kuchurhan
# Processing Record 38 of Set 8 | lichinga
# Processing Record 39 of Set 8 | maarianhamina
# Processing Record 40 of Set 8 | gumushane
# City not found. Skipping...
# Processing Record 41 of Set 8 | diamantino
# Processing Record 42 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 8 | mackay
# Processing Record 44 of Set 8 | kloulklubed
# Processing Record 45 of Set 8 | umm kaddadah
# Processing Record 46 of Set 8 | sawtell
# Processing Record 47 of Set 8 | lethem
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | weihai
# Processing Record 50 of Set 8 | diu
# Processing Record 1 of Set 9 | lerwick
# Processing Record 2 of Set 9 | manzhouli
# Processing Record 3 of Set 9 | souillac
# Processing Record 4 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 9 | araouane
# Processing Record 6 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 9 | pahrump
# Processing Record 8 of Set 9 | kensington
# Processing Record 9 of Set 9 | sept-iles
# Processing Record 10 of Set 9 | lompoc
# Processing Record 11 of Set 9 | oranjemund
# Processing Record 12 of Set 9 | qaqortoq
# Processing Record 13 of Set 9 | constantine
# Processing Record 14 of Set 9 | tigre
# Processing Record 15 of Set 9 | collipulli
# Processing Record 16 of Set 9 | angoram
# Processing Record 17 of Set 9 | kez
# Processing Record 18 of Set 9 | abu zabad
# Processing Record 19 of Set 9 | harnosand
# Processing Record 20 of Set 9 | teahupoo
# Processing Record 21 of Set 9 | lumeje
# Processing Record 22 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 9 | guia de isora
# Processing Record 24 of Set 9 | mount gambier
# Processing Record 25 of Set 9 | kattivakkam
# Processing Record 26 of Set 9 | kieta
# Processing Record 27 of Set 9 | whitianga
# Processing Record 28 of Set 9 | nizhniy tsasuchey
# Processing Record 29 of Set 9 | peno
# Processing Record 30 of Set 9 | alexandria
# Processing Record 31 of Set 9 | storforshei
# Processing Record 32 of Set 9 | bereda
# Processing Record 33 of Set 9 | port moresby
# Processing Record 34 of Set 9 | hofn
# Processing Record 35 of Set 9 | tekeli
# Processing Record 36 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 9 | zurrieq
# Processing Record 38 of Set 9 | chara
# Processing Record 39 of Set 9 | cap-aux-meules
# Processing Record 40 of Set 9 | havelock
# Processing Record 41 of Set 9 | sao jose da coroa grande
# Processing Record 42 of Set 9 | sistranda
# Processing Record 43 of Set 9 | candelaria
# Processing Record 44 of Set 9 | naliya
# Processing Record 45 of Set 9 | aykhal
# Processing Record 46 of Set 9 | sunbury
# Processing Record 47 of Set 9 | chapais
# Processing Record 48 of Set 9 | zilair
# Processing Record 49 of Set 9 | azanka
# Processing Record 50 of Set 9 | jiayuguan
# Processing Record 1 of Set 10 | berlevag
# Processing Record 2 of Set 10 | turbo
# Processing Record 3 of Set 10 | singaparna
# Processing Record 4 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 5 of Set 10 | rodrigues alves
# Processing Record 6 of Set 10 | peniche
# Processing Record 7 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 8 of Set 10 | eilenburg
# Processing Record 9 of Set 10 | pachino
# Processing Record 10 of Set 10 | atar
# Processing Record 11 of Set 10 | darnah
# Processing Record 12 of Set 10 | constitucion
# Processing Record 13 of Set 10 | poddorye
# Processing Record 14 of Set 10 | cochabamba
# Processing Record 15 of Set 10 | linhares
# Processing Record 16 of Set 10 | baykit
# Processing Record 17 of Set 10 | vanderhoof
# Processing Record 18 of Set 10 | sao raimundo das mangabeiras
# Processing Record 19 of Set 10 | cabo san lucas
# Processing Record 20 of Set 10 | mamallapuram
# Processing Record 21 of Set 10 | kalmunai
# Processing Record 22 of Set 10 | drezdenko
# Processing Record 23 of Set 10 | kavaratti
# Processing Record 24 of Set 10 | chabahar
# Processing Record 25 of Set 10 | craig
# Processing Record 26 of Set 10 | geraldton
# Processing Record 27 of Set 10 | cumbum
# Processing Record 28 of Set 10 | sydney
# Processing Record 29 of Set 10 | ambilobe
# Processing Record 30 of Set 10 | kuytun
# Processing Record 31 of Set 10 | aketi
# Processing Record 32 of Set 10 | orgtrud
# Processing Record 33 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 10 | taoudenni
# Processing Record 35 of Set 10 | chernyshevskiy
# Processing Record 36 of Set 10 | ust-tsilma
# Processing Record 37 of Set 10 | honiara
# Processing Record 38 of Set 10 | kangaatsiaq
# Processing Record 39 of Set 10 | tsumeb
# Processing Record 40 of Set 10 | koumac
# Processing Record 41 of Set 10 | garhi khairo
# Processing Record 42 of Set 10 | amarpur
# Processing Record 43 of Set 10 | huayang
# Processing Record 44 of Set 10 | karpathos
# Processing Record 45 of Set 10 | pringsewu
# Processing Record 46 of Set 10 | jalu
# Processing Record 47 of Set 10 | qiqihar
# Processing Record 48 of Set 10 | livingston
# Processing Record 49 of Set 10 | immokalee
# Processing Record 50 of Set 10 | kuusamo
# Processing Record 1 of Set 11 | burnie
# Processing Record 2 of Set 11 | cagliari
# Processing Record 3 of Set 11 | wuwei
# Processing Record 4 of Set 11 | savelugu
# Processing Record 5 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 6 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 11 | malakal
# Processing Record 8 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 11 | kallaste
# Processing Record 10 of Set 11 | lingyuan
# Processing Record 11 of Set 11 | sioux lookout
# Processing Record 12 of Set 11 | lensk
# Processing Record 13 of Set 11 | shwebo
# Processing Record 14 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 15 of Set 11 | san cristobal
# Processing Record 16 of Set 11 | shimoda
# Processing Record 17 of Set 11 | richards bay
# Processing Record 18 of Set 11 | rocha
# Processing Record 19 of Set 11 | luganville
# Processing Record 20 of Set 11 | antalaha
# Processing Record 21 of Set 11 | matay
# Processing Record 22 of Set 11 | svetlogorsk
# Processing Record 23 of Set 11 | ngunguru
# Processing Record 24 of Set 11 | broome
# Processing Record 25 of Set 11 | ville-marie
# Processing Record 26 of Set 11 | xudat
# Processing Record 27 of Set 11 | porto novo
# Processing Record 28 of Set 11 | portland
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 11 | westport
# Processing Record 32 of Set 11 | spirit river
# Processing Record 33 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 11 | troitsko-pechorsk
# Processing Record 35 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | bogoslovka
# Processing Record 37 of Set 11 | egvekinot
# Processing Record 38 of Set 11 | kamiichi
# Processing Record 39 of Set 11 | taunggyi
# Processing Record 40 of Set 11 | piopio
# Processing Record 41 of Set 11 | odweyne
# Processing Record 42 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 43 of Set 11 | sola
# Processing Record 44 of Set 11 | cockburn town
# Processing Record 45 of Set 11 | guerrero negro
# Processing Record 46 of Set 11 | rudbar
# Processing Record 47 of Set 11 | hami
# Processing Record 48 of Set 11 | carolina
# Processing Record 49 of Set 11 | gannan
# Processing Record 50 of Set 11 | bayir
# Processing Record 1 of Set 12 | ancona
# Processing Record 2 of Set 12 | viedma
# Processing Record 3 of Set 12 | la tuque
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | katherine
# Processing Record 6 of Set 12 | matara
# Processing Record 7 of Set 12 | odienne
# Processing Record 8 of Set 12 | oliva
# Processing Record 9 of Set 12 | sabha
# Processing Record 10 of Set 12 | port elizabeth
# Processing Record 11 of Set 12 | karachi
# Processing Record 12 of Set 12 | uva
# Processing Record 13 of Set 12 | ahipara
# Processing Record 14 of Set 12 | ulladulla
# Processing Record 15 of Set 12 | kortkeros
# Processing Record 16 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 12 | hovd
# Processing Record 18 of Set 12 | zabaykalsk
# Processing Record 19 of Set 12 | auki
# Processing Record 20 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 12 | beidao
# Processing Record 22 of Set 12 | mayumba
# Processing Record 23 of Set 12 | ust-ishim
# Processing Record 24 of Set 12 | saurimo
# Processing Record 25 of Set 12 | dingle
# Processing Record 26 of Set 12 | coromandel
# Processing Record 27 of Set 12 | gainesville
# Processing Record 28 of Set 12 | gatton
# Processing Record 29 of Set 12 | yamasaki
# Processing Record 30 of Set 12 | yelizovo
# Processing Record 31 of Set 12 | dakar
# Processing Record 32 of Set 12 | nam phong
# Processing Record 33 of Set 12 | deep river
# Processing Record 34 of Set 12 | grindavik
# Processing Record 35 of Set 12 | hermiston
# Processing Record 36 of Set 12 | dutse
# Processing Record 37 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 12 | akhmim
# Processing Record 39 of Set 12 | huarmey
# Processing Record 40 of Set 12 | gizo
# Processing Record 41 of Set 12 | isangel
# Processing Record 42 of Set 12 | salta
# Processing Record 43 of Set 12 | novyy urgal
# Processing Record 44 of Set 12 | stromness
# Processing Record 45 of Set 12 | mizan teferi
# Processing Record 46 of Set 12 | spasskoye
# Processing Record 47 of Set 12 | anadyr
# Processing Record 48 of Set 12 | ketchikan
# Processing Record 49 of Set 12 | boromo
# Processing Record 50 of Set 12 | revelstoke
# Processing Record 1 of Set 13 | chamalieres
# Processing Record 2 of Set 13 | hillsborough
# Processing Record 3 of Set 13 | tuy hoa
# Processing Record 4 of Set 13 | tateyama
# Processing Record 5 of Set 13 | galle
# Processing Record 6 of Set 13 | mount isa
# Processing Record 7 of Set 13 | ukiah
# Processing Record 8 of Set 13 | boende
# Processing Record 9 of Set 13 | fomboni
# Processing Record 10 of Set 13 | develi
# Processing Record 11 of Set 13 | farafangana
# Processing Record 12 of Set 13 | korla
# Processing Record 13 of Set 13 | urumqi
# Processing Record 14 of Set 13 | aginskoye
# Processing Record 15 of Set 13 | alanya
# Processing Record 16 of Set 13 | guilin
# Processing Record 17 of Set 13 | witrivier
# City not found. Skipping...
# Processing Record 18 of Set 13 | calvinia
# Processing Record 19 of Set 13 | beziers
# Processing Record 20 of Set 13 | le port
# Processing Record 21 of Set 13 | moroni
# Processing Record 22 of Set 13 | aksu
# Processing Record 23 of Set 13 | albury
# Processing Record 24 of Set 13 | yenagoa
# Processing Record 25 of Set 13 | dunedin
# Processing Record 26 of Set 13 | shizunai
# Processing Record 27 of Set 13 | motala
# Processing Record 28 of Set 13 | dalby
# Processing Record 29 of Set 13 | chaohu
# Processing Record 30 of Set 13 | bilibino
# Processing Record 31 of Set 13 | okha
# Processing Record 32 of Set 13 | tinqueux
# Processing Record 33 of Set 13 | rumonge
# Processing Record 34 of Set 13 | san ramon
# Processing Record 35 of Set 13 | isla vista
# Processing Record 36 of Set 13 | chicama
# Processing Record 37 of Set 13 | yabrud
# Processing Record 38 of Set 13 | nerchinsk
# Processing Record 39 of Set 13 | carlsbad
# Processing Record 40 of Set 13 | lazaro cardenas
# Processing Record 41 of Set 13 | moranbah
# Processing Record 42 of Set 13 | lakes entrance
# Processing Record 43 of Set 13 | la ronge
# Processing Record 44 of Set 13 | diffa
# Processing Record 45 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 46 of Set 13 | kutum
# Processing Record 47 of Set 13 | rockland
# Processing Record 48 of Set 13 | makakilo city
# Processing Record 49 of Set 13 | calama
# Processing Record 50 of Set 13 | qiongshan
# Processing Record 1 of Set 14 | umba
# Processing Record 2 of Set 14 | la rioja
# Processing Record 3 of Set 14 | naron
# Processing Record 4 of Set 14 | mandali
# Processing Record 5 of Set 14 | dobryatino
# Processing Record 6 of Set 14 | bronte
# Processing Record 7 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 14 | esmeraldas
# Processing Record 9 of Set 14 | yuli
# Processing Record 10 of Set 14 | phultala
# Processing Record 11 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 14 | san jeronimo
# Processing Record 13 of Set 14 | iracoubo
# Processing Record 14 of Set 14 | williams lake
# Processing Record 15 of Set 14 | kabelvag
# Processing Record 16 of Set 14 | fairbanks
# Processing Record 17 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 14 | ruidoso
# Processing Record 19 of Set 14 | los llanos de aridane
# Processing Record 20 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 14 | lodja
# Processing Record 22 of Set 14 | trincomalee
# Processing Record 23 of Set 14 | taian
# Processing Record 24 of Set 14 | am timan
# Processing Record 25 of Set 14 | waingapu
# Processing Record 26 of Set 14 | ulaangom
# Processing Record 27 of Set 14 | milton
# Processing Record 28 of Set 14 | zyryanka
# Processing Record 29 of Set 14 | russkaya polyana
# Processing Record 30 of Set 14 | kenai
# Processing Record 31 of Set 14 | tadine
# Processing Record 32 of Set 14 | adrian
# Processing Record 33 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 34 of Set 14 | baruun-urt
# Processing Record 35 of Set 14 | ayorou
# Processing Record 36 of Set 14 | gavle
# Processing Record 37 of Set 14 | tautira
# Processing Record 38 of Set 14 | kashan
# Processing Record 39 of Set 14 | high level
# Processing Record 40 of Set 14 | mitu
# Processing Record 41 of Set 14 | lucea
# Processing Record 42 of Set 14 | port hawkesbury
# Processing Record 43 of Set 14 | tarnogskiy gorodok
# Processing Record 44 of Set 14 | ajaccio
# Processing Record 45 of Set 14 | vytegra
# Processing Record 46 of Set 14 | moron
# Processing Record 47 of Set 14 | awjilah
# Processing Record 48 of Set 14 | hammerfest
# Processing Record 49 of Set 14 | manicore
# Processing Record 50 of Set 14 | itaquyry
# Processing Record 1 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 15 | aguimes
# Processing Record 3 of Set 15 | morondava
# Processing Record 4 of Set 15 | tecoanapa
# Processing Record 5 of Set 15 | cairns
# Processing Record 6 of Set 15 | icatu
# Processing Record 7 of Set 15 | sandwick
# Processing Record 8 of Set 15 | norman wells
# Processing Record 9 of Set 15 | redlands
# Processing Record 10 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 15 | port-gentil
# Processing Record 12 of Set 15 | maniitsoq
# Processing Record 13 of Set 15 | guarapari
# Processing Record 14 of Set 15 | thika
# Processing Record 15 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 15 | tambilil
# Processing Record 17 of Set 15 | birao
# Processing Record 18 of Set 15 | barranca
# Processing Record 19 of Set 15 | diego de almagro
# Processing Record 20 of Set 15 | tianpeng
# Processing Record 21 of Set 15 | goundam
# Processing Record 22 of Set 15 | willmar
# Processing Record 23 of Set 15 | iquitos
# Processing Record 24 of Set 15 | novyy svit
# Processing Record 25 of Set 15 | buala
# Processing Record 26 of Set 15 | netivot
# Processing Record 27 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 15 | nabire
# Processing Record 29 of Set 15 | tazovskiy
# Processing Record 30 of Set 15 | katsuura
# Processing Record 31 of Set 15 | sao gabriel da cachoeira
# Processing Record 32 of Set 15 | kaduqli
# Processing Record 33 of Set 15 | galesburg
# Processing Record 34 of Set 15 | obo
# Processing Record 35 of Set 15 | muana
# Processing Record 36 of Set 15 | vestmannaeyjar
# Processing Record 37 of Set 15 | srednekolymsk
# Processing Record 38 of Set 15 | marawi
# Processing Record 39 of Set 15 | coihaique
# Processing Record 40 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 15 | willowmore
# Processing Record 42 of Set 15 | tsiroanomandidy
# Processing Record 43 of Set 15 | salinopolis
# Processing Record 44 of Set 15 | tongliao
# Processing Record 45 of Set 15 | ranipur
# Processing Record 46 of Set 15 | vysokopillya
# Processing Record 47 of Set 15 | biak
# Processing Record 48 of Set 15 | dogondoutchi
# Processing Record 49 of Set 15 | hun
# Processing Record 50 of Set 15 | cuamba
# Processing Record 1 of Set 16 | walvis bay
# Processing Record 2 of Set 16 | aswan
# Processing Record 3 of Set 16 | asau
# Processing Record 4 of Set 16 | praia
# Processing Record 5 of Set 16 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 16 | angoche
# Processing Record 7 of Set 16 | batemans bay
# Processing Record 8 of Set 16 | chulman
# Processing Record 9 of Set 16 | pierre
# Processing Record 10 of Set 16 | ponta delgada
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Pangnirtung  66.1451  -65.7125     42.80        75          75
# 1           Olinda  -8.0089  -34.8553     76.73        73          40
# 2       Payakumbuh  -0.2202  100.6308     68.54        95         100
# 3         Hermanus -34.4187   19.2345     53.80        79          49
# 4     Nizhneivkino  58.1940   49.5214     53.29        81         100
# 5     Punta Arenas -53.1500  -70.9167     42.91        75           0
# 6  Bambous Virieux -20.3428   57.7575     70.21        78          20
# 7           Albany  42.6001  -73.9662     65.64        93         100
# 8         Meulaboh   4.1363   96.1285     75.27        88         100
# 9          College  64.8569 -147.8028     55.38        57         100
#
#    Wind Speed Country Current Description
# 0       17.27      CA       broken clouds
# 1       12.66      BR    scattered clouds
# 2        1.70      ID     overcast clouds
# 3        3.09      ZA    scattered clouds
# 4       12.44      RU     overcast clouds
# 5       11.50      CL           clear sky
# 6        6.91      MU          light rain
# 7        3.76      US          light rain
# 8        3.31      ID       moderate rain
# 9        4.61      US     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
